# %% [markdown]
# # INFORMACIÓN DEL PROYECTO

# %% [markdown]
# Este proyecto se basa en una *"prueba técnica para Celon Media Agency*". Se requiere:
# 1. **Limpieza de datos**: productos.csv, tiendas.csv y ventas.csv.
# 2. **Consolidación de la información en tablas**
# 3. **Análisis exploratorio**:
#    - Estadísticas descriptivas.
#    - Visualizaciones.
#    - Insights relevantes y conclusiones.
# 4. **Modelo predictivo**
# 5. **Análisis final del proyecto**

# %% [markdown]
# ## DATASETS Y EXPLORATORIO INICIAL

# %% [markdown]
# #### Librerías necesarias

# %%
import zipfile
import pandas as pd

# %%
# Extraemos los archivos de la carpeta Prueba_Tecnica.zip
with zipfile.ZipFile(r'C:\Users\Steven\Desktop\Prueba Técnica- Data Scientist\Prueba-T-cnica-Junior-Data-Scientist\data\Prueba_Tecnica.zip') as zip_ref:
    zip_ref.extractall(r'C:\Users\Steven\Desktop\Prueba Técnica- Data Scientist\Prueba-T-cnica-Junior-Data-Scientist\data')
print(f"Archivos extraídos a: data")
# Out:
# Archivos extraídos a: data

# %% [markdown]
# ### Productos

# %%
# Leemos el archivo productos.csv
productos = pd.read_csv('..\\data\\productos.csv')
productos
# Out:
#     product_id           product_name           category  price   cost  \
# 0          101       Cafetera Premium  Electrodomesticos     90   60.0
# 1          102        Cafetera Básica  Electrodomesticos     60   40.0
# 2          103  Tostadora 2 rebanadas  Electrodomesticos     30   20.0
# 3          104  Tostadora 4 rebanadas  Electrodomesticos     50   30.0
# 4          105      Batidora Compacta  Electrodomesticos     80    NaN
# 5          106           Lavadora 7kg  Electrodomesticos    300  200.0
# 6          107     Tableta 8 pulgadas        Electrónica    120   95.0
# 7          108  Smartphone Gama Media        Electrónica    250  180.0
# 8          109   Smartphone Gama Alta        Electrónica    500  380.0
# 9          110          Laptop Básica        Electrónica    450  350.0
# 10         111     Laptop Profesional        Electrónica    900  700.0
# 11         112       Cámara Deportiva        Electrónica    200  150.0
# ...

# %%
# Mostramos la información del archivo productos.csv
productos.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21 entries, 0 to 20
# Data columns (total 7 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   product_id    21 non-null     int64
#  1   product_name  21 non-null     object
#  2   category      21 non-null     object
#  3   price         21 non-null     int64
#  4   cost          20 non-null     float64
#  5   launch_date   21 non-null     object
#  6   status        21 non-null     object
# dtypes: float64(1), int64(2), object(4)
# memory usage: 1.3+ KB

# %%
# Mostramos la descripción del archivo productos.csv
productos.describe(include = "all")
# Out:
#         product_id       product_name           category       price  \
# count    21.000000                 21                 21   21.000000
# unique         NaN                 20                  3         NaN
# top            NaN  Pack Cuchillos x3  Electrodomesticos         NaN
# freq           NaN                  2                 10         NaN
# mean    110.809524                NaN                NaN  208.571429
# std       5.938174                NaN                NaN  254.672058
# min     101.000000                NaN                NaN   15.000000
# 25%     106.000000                NaN                NaN   40.000000
# 50%     111.000000                NaN                NaN   90.000000
# 75%     116.000000                NaN                NaN  250.000000
# max     120.000000                NaN                NaN  900.000000
#
#               cost launch_date  status
# count    20.000000          21      21
# unique         NaN          18       3
# ...

# %% [markdown]
# ### Tiendas

# %%
# Leemos el archivo ventas.csv
tiendas = pd.read_csv('..\\data\\tiendas.csv')
tiendas
# Out:
#    store_id               store_name    location          manager opening_date
# 0       501            Tienda Centro      Madrid       Juan Perez   2022-01-10
# 1       502             Tienda Norte   Barcelona      Laura Lopez   2022-02-05
# 2       503               Tienda Sur     Sevilla   Carlos Ramirez   2022-03-01
# 3       504              Tienda Este    Valencia        Ana Gomez   2022-04-15
# 4       505             Tienda Oeste      Bilbao  Pedro Hernandez   2022-05-01
# 5       506         Tienda Duplicada      Madrid     Julian Casas   2022-05-20
# 6       507             Tienda Móvil  Itinerante       Maria Diaz   2022-06-10
# 7       508             Pop-up Store   Barcelona                -   2023-01-01
# 8       509            Tienda Online      Online  Virtual Manager   2022-07-01
# 9       509  Tienda Online Duplicada      Online  Virtual Manager   2022-07-01

# %%
# Mostramos la información del archivo tiendas.csv
tiendas.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   store_id      10 non-null     int64
#  1   store_name    10 non-null     object
#  2   location      10 non-null     object
#  3   manager       10 non-null     object
#  4   opening_date  10 non-null     object
# dtypes: int64(1), object(4)
# memory usage: 532.0+ bytes

# %%
# Mostramos la descripción del archivo tiendas.csv
tiendas.describe(include = "all")
# Out:
#           store_id     store_name location          manager opening_date
# count    10.000000             10       10               10           10
# unique         NaN             10        7                9            9
# top            NaN  Tienda Centro   Madrid  Virtual Manager   2022-07-01
# freq           NaN              1        2                2            2
# mean    505.400000            NaN      NaN              NaN          NaN
# std       2.875181            NaN      NaN              NaN          NaN
# min     501.000000            NaN      NaN              NaN          NaN
# 25%     503.250000            NaN      NaN              NaN          NaN
# 50%     505.500000            NaN      NaN              NaN          NaN
# 75%     507.750000            NaN      NaN              NaN          NaN
# max     509.000000            NaN      NaN              NaN          NaN

# %% [markdown]
# ### Ventas

# %%
# Leemos el archivo ventas.csv
ventas = pd.read_csv('..\\data\\ventas.csv')
ventas
# Out:
#     sale_id        date  store_id  product_id  units_sold  total_revenue  \
# 0     10001  2023-01-02       501         101           5            450
# 1     10002  2023-01-03       501         102           3            180
# 2     10003  2023-01-03       501         105           1             80
# 3     10004  2023-01-15       502         103           2             60
# 4     10005  2023-02-10       502         104           1             50
# 5     10006  2023-02-11       502         106           1            300
# 6     10007  2023-02-15       503         107           2            240
# 7     10008  2023-02-16       503         108           1            250
# 8     10009  2023-02-20       504         109           1            500
# 9     10010  2023-03-01       501         110           2            900
# 10    10011  2023-03-05       506         105           2            160
# 11    10012  2023-03-05       506         117           5            200
# ...

# %%
# Mostramos la información del archivo ventas.csv
ventas.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 33 entries, 0 to 32
# Data columns (total 7 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   sale_id        33 non-null     int64
#  1   date           33 non-null     object
#  2   store_id       33 non-null     int64
#  3   product_id     33 non-null     int64
#  4   units_sold     33 non-null     int64
#  5   total_revenue  33 non-null     int64
#  6   total_cost     32 non-null     object
# dtypes: int64(5), object(2)
# memory usage: 1.9+ KB

# %%
# Mostramos la descripción del archivo ventas.csv
ventas.describe(include = "all")
# Out:
#             sale_id        date    store_id  product_id  units_sold  \
# count      33.00000          33   33.000000   33.000000   33.000000
# unique          NaN          28         NaN         NaN         NaN
# top             NaN  2023-05-02         NaN         NaN         NaN
# freq            NaN           2         NaN         NaN         NaN
# mean    10017.00000         NaN  519.151515  191.454545    2.484848
# std         9.66954         NaN   86.183351  259.409436    1.872852
# min     10001.00000         NaN  501.000000  101.000000    1.000000
# 25%     10009.00000         NaN  502.000000  105.000000    1.000000
# 50%     10017.00000         NaN  504.000000  112.000000    2.000000
# 75%     10025.00000         NaN  506.000000  119.000000    3.000000
# max     10033.00000         NaN  999.000000  999.000000   10.000000
#
#         total_revenue total_cost
# count       33.000000         32
# unique            NaN         24
# top               NaN         60
# ...
